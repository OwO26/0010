# %% [markdown]
# # API Obtain via Baidu map

# %% [markdown]
# Considering that I need to get a lot of API data through Baidu Maps, while getting a lot of data at once will cause my python to crash, I grab them in batches according to different topics.

# %% [markdown]
# To get Baidu api key via: https://lbsyun.baidu.com/

# %%
from urllib import request
from urllib.parse import quote
import json
import string
from pandas.core.frame import DataFrame

# %% [markdown]
# ## API of metro station in Shenzhen

# %% [markdown]
# ### API KEY

# %%
#ak = 'xnrnvAZtT68KPGaw5MRcHkhMPlf8hAFi' #API key
#ak = 'cGCdY6KHFma1t35LhDUZ13WI5qG1ni24' # second API key
#ak = 'WdzbAKBkAombHOV93PjyjR2PihnGGGNQ' # third API key
#ak= 'nt0YLRVb5Z7emBrqYTKcpHyMosFTsEGX' # forth API key

# %%
subwayList = []
resultss_name=[]
resultss_lat=[]
resultss_lng=[]
resultss_address=[]
with open('metro_name', 'r') as f:
    subwayList=f.read().strip(',').split('\n')

def startGet():
    for emp in subwayList:
        print(emp)
        getLocation(address=emp)

def getLocation(address='address'):
    url = "http://api.map.baidu.com/place/v2/search?query="+address+"&tag=地铁站&region=深圳市&output=json&ak=xnrnvAZtT68KPGaw5MRcHkhMPlf8hAFi"
    url = quote(url, safe=string.printable)
    req = request.urlopen(url)
    res = req.read().decode('utf-8','ignore').replace(u'\xa9', u'')
    result = json.loads(res)
    print(result)
    
    result233=[]
    result233.append(result)
    results=[]
    results.append(result233[0])
    resultss_name.append(results[0]['results'][0]['name'])
    resultss_lat.append(results[0]['results'][0]['location']['lat'])
    resultss_lng.append(results[0]['results'][0]['location']['lng'])

if __name__ == '__main__':
    startGet()
# Out:
# 罗湖地铁站
# ...

# %%
c={'name':resultss_name,
  "lat":resultss_lat,
  "lng":resultss_lng}
metro_data=DataFrame(c)
print(metro_data)
# Out:
#      name        lat         lng
# 0      罗湖  22.537936  114.125317
# 1      国贸  22.546055  114.125156
# 2      老街  22.550870  114.122738
# 3     大剧院  22.547971  114.114678
# 4     科学馆  22.546109  114.102113
# ..    ...        ...         ...
# 306   东庵站  22.695563  114.060317
# 307  高新区西  22.694782  114.065589
# 308   高新园  22.546035  113.960423
# 309  高新区东  22.695231  114.077595
# 310   下围站  22.696643  114.084133
#
# [311 rows x 3 columns]

# %% [markdown]
# The first part of api location of 河东站 (Hedong Station) is a bus station. I change it to second part of api location, which is the metro station location I need.

# %%
metro_data=metro_data.replace(22.575025, 22.713862)
metro_data=metro_data.replace(113.886817, 114.067583)

# %%
metro_data=metro_data.set_index('name')

# %%
metro_data.to_csv("output_data/metro.csv")

# %% [markdown]
# ## API of primary hospital in Shenzhen

# %%
subwayList = []
resultss_name=[]
resultss_lat=[]
resultss_lng=[]
resultss_district=[]
with open('hospital_name', 'r') as f:
    subwayList=f.read().strip(',').split('\n')

def startGet():
    for emp in subwayList:
        print(emp)
        getLocation(address=emp)

def getLocation(address='address'):
    url = "http://api.map.baidu.com/place/v2/search?query="+address+"&tag=医院&region=深圳市&output=json&ak=xnrnvAZtT68KPGaw5MRcHkhMPlf8hAFi"
    url = quote(url, safe=string.printable)
    req = request.urlopen(url)
    res = req.read().decode('utf-8','ignore').replace(u'\xa9', u'')
    result = json.loads(res)
    print(result)
    
    result233=[]
    result233.append(result)
    results=[]
    results.append(result233[0])
    resultss_name.append(results[0]['results'][0]['name'])
    resultss_lat.append(results[0]['results'][0]['location']['lat'])
    resultss_lng.append(results[0]['results'][0]['location']['lng'])
    resultss_district.append(results[0]['results'][0]['area'])

if __name__ == '__main__':
    startGet()
# Out:
# 北京大学深圳医院
# ...

# %%
c={'name':resultss_name,
  "lat":resultss_lat,
  "lng":resultss_lng,
  "district":resultss_district}
hos_data=DataFrame(c)
print(hos_data)
# Out:
#                   name        lat         lng district
# 0             北京大学深圳医院  22.562360  114.055656      福田区
# 1             香港大学深圳医院  22.531953  114.002664      福田区
# 2            深圳市第二人民医院  22.563052  114.092161      福田区
# 3               深圳市中医院  22.542855  114.092006      福田区
# 4           中山大学附属第八医院  22.544356  114.086159      福田区
# 5      广州中医药大学深圳医院(福田)  22.565023  114.048841      福田区
# 6         深圳市福田区第二人民医院  22.572150  114.065450      福田区
# 7               深圳景田医院  22.555173  114.048692      福田区
# 8              深圳市人民医院  22.563688  114.134149      罗湖区
# 9        深圳市康宁医院(罗湖院区)  22.570543  114.137226      罗湖区
# 10          深圳市罗湖区人民医院  22.544243  114.128570      罗湖区
# 11              罗湖区中医院  22.571769  114.187206      罗湖区
# 12       深圳出入境边防检查总站医院  22.579798  114.109342      罗湖区
# 13          深圳市盐田区人民医院  22.563947  114.240054      盐田区
# 14             深圳大学总医院  22.600715  113.993909      南山区
# 15     中国医学科学院阜外医院深圳医院  22.562695  113.954329      南山区
# ...

# %%
hos_data.duplicated(['lat'])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
hos_data=hos_data.drop_duplicates(['lat'])

# %%
hos_data=hos_data.set_index('name')

# %%
hos_data.to_csv("output_data/hospital.csv")

# %% [markdown]
# ## API of large industrial park in Shenzhen

# %% [markdown]
# During this part, my baidu api key already arrive limitation, so I change another api key. When reproduction, if this is not available, please apply a new key via https://lbsyun.baidu.com/.

# %%
subwayList = []
resultss_name=[]
resultss_lat=[]
resultss_lng=[]
resultss_district=[]
with open('industry_name', 'r') as f:
    subwayList=f.read().strip(',').split('\n')

def startGet():
    for emp in subwayList:
        print(emp)
        getLocation(address=emp)

def getLocation(address='address'):
    url = "http://api.map.baidu.com/place/v2/search?query="+address+"&tag=产业园&region=深圳市&output=json&ak=cGCdY6KHFma1t35LhDUZ13WI5qG1ni24"
    url = quote(url, safe=string.printable)
    req = request.urlopen(url)
    res = req.read().decode('utf-8','ignore').replace(u'\xa9', u'')
    result = json.loads(res)
    print(result)
    
    result233=[]
    result233.append(result)
    results=[]
    results.append(result233[0])
    resultss_name.append(results[0]['results'][0]['name'])
    resultss_lat.append(results[0]['results'][0]['location']['lat'])
    resultss_lng.append(results[0]['results'][0]['location']['lng'])
    resultss_district.append(results[0]['results'][0]['area'])

if __name__ == '__main__':
    startGet()
# Out:
# 华强创意产业园
# ...

# %%
c={'name':resultss_name,
  "lat":resultss_lat,
  "lng":resultss_lng,
  "district":resultss_district}
indu_data=DataFrame(c)
print(indu_data)
# Out:
#                    name        lat         lng district
# 0               华强创意产业园  22.743846  113.964080      光明区
# 1          深圳市生物医药创新产业园  22.742392  114.410902      坪山区
# 2           福田国际电子商务产业园  22.569353  114.062568      福田区
# 3        中国(深圳)新媒体广告产业园  22.531178  114.042240      福田区
# 4             湾区人工智能产业园  22.612721  113.869077      宝安区
# 5             深圳市互联网产业园  22.570363  114.179031      罗湖区
# 6            大百汇生命健康产业园  22.573110  114.257553      盐田区
# 7                高新奇科技园  22.580244  113.927790      宝安区
# 8                 长丰工业园  22.586246  113.932680      宝安区
# 9                 庭威工业园  22.583754  113.928440      宝安区
# 10           立新湖福宁高新产业园  22.692436  113.836509      宝安区
# 11                泰熙产业园  22.740323  113.996020      光明区
# 12          阿凡达·新桥创新产业园  22.745110  113.849745      宝安区
# 13           富比伦鼎丰高新产业园  22.754798  113.864009      宝安区
# 14        碧桂园(深圳)机器人产业园  22.793430  113.833646      宝安区
# 15            中泰信息技术产业园  22.700379  113.979810      宝安区
# ...

# %%
indu_data.duplicated(['lat'])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# dtype: bool

# %%
indu_data=indu_data.drop_duplicates(['lat'])

# %%
indu_data=indu_data.set_index('name')

# %%
indu_data.to_csv("output_data/industry.csv")

# %% [markdown]
# ## API of main office building in Shenzhen

# %%
subwayList = []
resultss_name=[]
resultss_lat=[]
resultss_lng=[]
resultss_district=[]
with open('building_name', 'r') as f:
    subwayList=f.read().strip(',').split('\n')

def startGet():
    for emp in subwayList:
        print(emp)
        getLocation(address=emp)

def getLocation(address='address'):
    url = "http://api.map.baidu.com/place/v2/search?query="+address+"&tag=写字楼&region=深圳市&output=json&ak=cGCdY6KHFma1t35LhDUZ13WI5qG1ni24"
    url = quote(url, safe=string.printable)
    req = request.urlopen(url)
    res = req.read().decode('utf-8','ignore').replace(u'\xa9', u'')
    result = json.loads(res)
    print(result)
    
    result233=[]
    result233.append(result)
    results=[]
    results.append(result233[0])
    resultss_name.append(results[0]['results'][0]['name'])
    resultss_lat.append(results[0]['results'][0]['location']['lat'])
    resultss_lng.append(results[0]['results'][0]['location']['lng'])
    resultss_district.append(results[0]['results'][0]['area'])

if __name__ == '__main__':
    startGet()
# Out:
# 龙岗创投大厦
# ...

# %%
c={'name':resultss_name,
  "lat":resultss_lat,
  "lng":resultss_lng,
  "district":resultss_district}
off_data=DataFrame(c)
print(off_data)
# Out:
#         name        lat         lng district
# 0     龙岗创投大厦  22.727296  114.221904      龙岗区
# 1   深圳国际文化大厦  22.545136  114.084165      福田区
# 2       中银大厦  22.553055  114.073878      福田区
# 3       新闻大厦  22.547562  114.109086      福田区
# 4       北方大厦  22.546020  114.091340      福田区
# ..       ...        ...         ...      ...
# 64    华润置地大厦  22.547286  113.959560      南山区
# 65      建工大厦  22.557009  114.234130      盐田区
# 66      建业大厦  22.543022  114.023061      福田区
# 67    经济发展大厦  22.786787  113.901400      光明区
# 68    坪山投资大厦  22.702038  114.353111      坪山区
#
# [69 rows x 4 columns]

# %%
off_data.duplicated(['lat'])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# Length: 69, dtype: bool

# %%
off_data=off_data.drop_duplicates(['lat'])

# %%
off_data=off_data.set_index('name')

# %%
off_data.to_csv("output_data/building.csv")

# %% [markdown]
# ## API of main farm in Shenzhen

# %%
subwayList = []
resultss_name=[]
resultss_lat=[]
resultss_lng=[]
resultss_district=[]
with open('farm_name', 'r') as f:
    subwayList=f.read().strip(',').split('\n')

def startGet():
    for emp in subwayList:
        print(emp)
        getLocation(address=emp)

def getLocation(address='address'):
    url = "http://api.map.baidu.com/place/v2/search?query="+address+"&tag=农场&region=深圳市&output=json&ak=xnrnvAZtT68KPGaw5MRcHkhMPlf8hAFi"
    url = quote(url, safe=string.printable)
    req = request.urlopen(url)
    res = req.read().decode('utf-8','ignore').replace(u'\xa9', u'')
    result = json.loads(res)
    print(result)
    
    result233=[]
    result233.append(result)
    results=[]
    results.append(result233[0])
    resultss_name.append(results[0]['results'][0]['name'])
    resultss_lat.append(results[0]['results'][0]['location']['lat'])
    resultss_lng.append(results[0]['results'][0]['location']['lng'])

if __name__ == '__main__':
    startGet()
# Out:
# 广东省深圳市大鹏区鹏城鹏飞路310号
# {'status': 0, 'message': 'ok', 'result_type': 'address_type', 'results': [{'name': '鹏飞路310号', 'location': {'lat': 22.599179, 'lng': 114.529874}, 'address': '龙岗区'}]}
# 广东省深圳市光明区光明街道办新羌社区北岗菜场北15号
# ...

# %%
d={'name':resultss_name,
  "lat":resultss_lat,
  "lng":resultss_lng}
farm_data=DataFrame(d)
print(farm_data)
# Out:
#              name        lat         lng
# 0         鹏飞路310号  22.599179  114.529874
# 1          双晖现代农业  22.816467  113.952758
# 2           大王山广场  22.715026  113.813282
# 3       同乐社区浪背工业区  22.742671  114.336298
# 4            新羌社区  22.806162  113.949302
# 5          凤歧路20号  22.691380  114.116708
# 6           东涌旅游区  22.497243  114.588685
# 7             新大路  22.560552  114.508215
# 8   华润五丰农产品深圳有限公司  22.566243  113.911577
# 9        灿城农产品物流园  22.728188  114.092094
# 10         根玉路15号  22.729461  113.897180
# 11         金源路16号  22.683369  114.243216
# 12  深圳市光明区光明街道办事处  22.768958  113.954120
# 13          富临路2号  22.801376  114.341401
# 14         杓妈岭工业区  22.614782  114.128270
# 15            深坑村  22.638060  114.173079
# 16          龙山工业区  22.606706  114.145020
# 17         创业二路北巷  22.576832  113.906990
# 18  深圳市鼎盛肉业食品有限公司  22.709479  113.965449

# %%
farm_data.duplicated(['lat'])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# dtype: bool

# %%
farm_data.to_csv("output_data/farm.csv")

# %% [markdown]
# ## API of main shopping centrals in Shenzhen

# %%
subwayList = []
resultss_name=[]
resultss_lat=[]
resultss_lng=[]
resultss_district=[]
with open('shop_name', 'r') as f:
    subwayList=f.read().strip(',').split('\n')

def startGet():
    for emp in subwayList:
        print(emp)
        getLocation(address=emp)

def getLocation(address='address'):
    url = "http://api.map.baidu.com/place/v2/search?query="+address+"&tag=超市&region=深圳市&output=json&ak=json&ak=cGCdY6KHFma1t35LhDUZ13WI5qG1ni24"
    url = quote(url, safe=string.printable)
    req = request.urlopen(url)
    res = req.read().decode('utf-8','ignore').replace(u'\xa9', u'')
    result = json.loads(res)
    print(result)
    
    result233=[]
    result233.append(result)
    results=[]
    results.append(result233[0])
    resultss_name.append(results[0]['results'][0]['name'])
    resultss_lat.append(results[0]['results'][0]['location']['lat'])
    resultss_lng.append(results[0]['results'][0]['location']['lng'])
    resultss_district.append(results[0]['results'][0]['area'])

if __name__ == '__main__':
    startGet()
# Out:
# 华润万家(龙华店)
# ...

# %%
d={'name':resultss_name,
  "lat":resultss_lat,
  "lng":resultss_lng,
   "district":resultss_district
  }
shop_data=DataFrame(d)
print(shop_data)
# Out:
#            name        lat         lng district
# 0     华润万家(龙华店)  22.660378  114.027651      龙华区
# 1     华润万家(益田店)  22.529075  114.063573      福田区
# 2     华润万家(沙井店)  22.734317  113.834571      宝安区
# 3     华润万家(横岗店)  22.643500  114.197948      龙岗区
# 4     华润万家(宝安店)  22.566492  113.911443      宝安区
# ..          ...        ...         ...      ...
# 56   华润万家(登良路店)  22.517555  113.930565      南山区
# 57  华润万家(东方沁园店)  22.730895  114.230387      龙岗区
# 58   华润万家(华清园店)  22.559426  114.158222      罗湖区
# 59   华润万家(水山缘店)  22.606273  114.147458      龙岗区
# 60    华润万家(麓园店)  22.738238  114.226041      龙岗区
#
# [61 rows x 4 columns]

# %%
shop_data.duplicated(['lat'])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# Length: 61, dtype: bool

# %%
shop_data=shop_data.drop_duplicates(['lat'])

# %%
shop_data.to_csv("output_data/shop.csv")

# %% [markdown]
# ## API of main park in Shenzhen

# %%
subwayList = []
resultss_name=[]
resultss_lat=[]
resultss_lng=[]
resultss_district=[]
with open('park_name', 'r') as f:
    subwayList=f.read().strip(',').split('\n')

def startGet():
    for emp in subwayList:
        print(emp)
        getLocation(address=emp)

def getLocation(address='address'):
    url = "http://api.map.baidu.com/place/v2/search?query="+address+"&tag=公园&region=深圳市&output=json&ak=cGCdY6KHFma1t35LhDUZ13WI5qG1ni24"
    url = quote(url, safe=string.printable)
    req = request.urlopen(url)
    res = req.read().decode('utf-8','ignore').replace(u'\xa9', u'')
    result = json.loads(res)
    print(result)
    
    result233=[]
    result233.append(result)
    results=[]
    results.append(result233[0])
    resultss_name.append(results[0]['results'][0]['name'])
    resultss_lat.append(results[0]['results'][0]['location']['lat'])
    resultss_lng.append(results[0]['results'][0]['location']['lng'])
    resultss_district.append(results[0]['results'][0]['area'])

if __name__ == '__main__':
    startGet()
# Out:
# 福田红树林生态公园
# ...

# %%
d={'name':resultss_name,
  "lat":resultss_lat,
  "lng":resultss_lng,
  'district':resultss_district}
park_data=DataFrame(d)
print(park_data)
# Out:
#          name        lat         lng district
# 0   福田红树林生态公园  22.516544  114.046887      福田区
# 1        皇岗公园  22.523863  114.064550      福田区
# 2      深圳中心公园  22.558082  114.084904      福田区
# 3       笔架山公园  22.568123  114.086519      福田区
# 4        荔枝公园  22.551853  114.109029      福田区
# ..        ...        ...         ...      ...
# 64     光明森林公园  22.771213  113.974658      光明区
# 65    松子坑森林公园  22.729104  114.368488      坪山区
# 66     章阁城市公园  22.749189  114.018502      龙华区
# 67    樟坑径城市公园  22.686003  114.088045      龙华区
# 68      深圳湾公园  22.528370  114.003481      福田区
#
# [69 rows x 4 columns]

# %%
park_data.duplicated(['lat'])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# Length: 69, dtype: bool

# %%
park_data=park_data.drop_duplicates(['lat'])

# %%
park_data.to_csv("output_data/park.csv")

# %% [markdown]
# # _____

# %% [markdown]
# Note: If the csv file needs to be opened and viewed in Excel, it is required that the file be re-encoded to UTF-8 BOM by Notepad.
