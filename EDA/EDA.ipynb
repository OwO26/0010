# %% [markdown]
# # EDA

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import libpysal as ps
from shapely.geometry import Point

# %%
sh = gpd.read_file("shp/---polygon.shp") 
shp=gpd.read_file("shp/深圳市_乡镇边界.shp") 
m = pd.read_csv("output_data/metro.csv")
h =pd.read_csv("output_data/hospital.csv")
i =pd.read_csv("output_data/industry.csv")
b =pd.read_csv("output_data/building.csv")
f =pd.read_csv("output_data/farm.csv")
s =pd.read_csv("output_data/shop.csv")
p =pd.read_csv("output_data/park.csv")
pop=pd.read_csv("Shenzhen_population.csv")

# %%
crs = {'init': 'epsg:4326'}
shp1 = shp.to_crs("EPSG:4326")

# %% [markdown]
# ## Metro

# %%
#Transfrom lng and lat to geometry with epsg4326
geometry = [Point(xy) for xy in zip(m['lng'], m['lat'])]
mgdf = gpd.GeoDataFrame(m, crs=crs, geometry=geometry)
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pyproj/crs/crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
#plot
ax = shp1.plot(cmap = 'jet', column = 'Layer', figsize=(10,10)) 
mgdf.plot(ax=ax,color='yellow')
# Out:
# <AxesSubplot:>

# %%
mgdf.to_csv('output_data/for_qgis.csv')

# %% [markdown]
# ## Hospital

# %%
#Transfrom lng and lat to geometry with epsg4326
geometry = [Point(xy) for xy in zip(h['lng'], h['lat'])]
hgdf = gpd.GeoDataFrame(h, crs=crs, geometry=geometry)
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pyproj/crs/crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
#plot
ax = shp1.plot(cmap = 'jet', column = 'Layer', figsize=(10,10)) 
hgdf.plot(ax=ax,color='m')
# Out:
# <AxesSubplot:>

# %%
hgdf.to_file('output_data/hospital.shp')

# %% [markdown]
# ## Industry

# %%
#Transfrom lng and lat to geometry with epsg4326
geometry = [Point(xy) for xy in zip(i['lng'], i['lat'])]
igdf = gpd.GeoDataFrame(i, crs=crs, geometry=geometry)
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pyproj/crs/crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
#plot
points_clip = gpd.clip(igdf, shp1)
ax = shp1.plot(cmap = 'jet', column = 'Layer', figsize=(10,10)) 
points_clip.plot(ax=ax,color='#eeefff')
# Out:
# /tmp/ipykernel_2361/1556217671.py:2: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: +init=epsg:4326 +type=crs
# Right CRS: EPSG:4326
#
#   points_clip = gpd.clip(igdf, shp1)
# <AxesSubplot:>

# %%
hgdf.to_file('output_data/industry.shp')

# %% [markdown]
# ## Office building

# %%
#Transfrom lng and lat to geometry with epsg4326
geometry = [Point(xy) for xy in zip(b['lng'], b['lat'])]
bgdf = gpd.GeoDataFrame(b, crs=crs, geometry=geometry)
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pyproj/crs/crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
#plot
points_clip = gpd.clip(bgdf, shp1)
ax = shp1.plot(cmap = 'jet', column = 'Layer', figsize=(10,10)) 
points_clip.plot(ax=ax,color='r')
# Out:
# /tmp/ipykernel_2361/3895667596.py:2: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: +init=epsg:4326 +type=crs
# Right CRS: EPSG:4326
#
#   points_clip = gpd.clip(bgdf, shp1)
# <AxesSubplot:>

# %%
bgdf.to_file('output_data/office.shp')

# %% [markdown]
# ## Farm

# %%
#Transfrom lng and lat to geometry with epsg4326
geometry = [Point(xy) for xy in zip(f['lng'], f['lat'])]
fgdf = gpd.GeoDataFrame(f, crs=crs, geometry=geometry)
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pyproj/crs/crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
#plot
points_clip = gpd.clip(fgdf, shp1)
ax = shp1.plot(cmap = 'jet', column = 'Layer', figsize=(10,10)) 
points_clip.plot(ax=ax,color='c')
# Out:
# /tmp/ipykernel_2361/3510422757.py:2: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: +init=epsg:4326 +type=crs
# Right CRS: EPSG:4326
#
#   points_clip = gpd.clip(fgdf, shp1)
# <AxesSubplot:>

# %%
fgdf.to_file('output_data/farm.shp')

# %% [markdown]
# ## Shop

# %%
#Transfrom lng and lat to geometry with epsg4326
geometry = [Point(xy) for xy in zip(s['lng'], s['lat'])]
sgdf = gpd.GeoDataFrame(s, crs=crs, geometry=geometry)

#plot
points_clip = gpd.clip(sgdf, shp1)
ax = shp1.plot(cmap = 'jet', column = 'Layer', figsize=(10,10)) 
points_clip.plot(ax=ax,color='m')
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pyproj/crs/crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# /tmp/ipykernel_2361/836267605.py:6: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: +init=epsg:4326 +type=crs
# Right CRS: EPSG:4326
#
#   points_clip = gpd.clip(sgdf, shp1)
# <AxesSubplot:>

# %%
sgdf.to_file('output_data/supermarket.shp')

# %% [markdown]
# ## Park

# %%
#Transfrom lng and lat to geometry with epsg4326
geometry = [Point(xy) for xy in zip(p['lng'], p['lat'])]
pgdf = gpd.GeoDataFrame(p, crs=crs, geometry=geometry)

#plot
points_clip = gpd.clip(pgdf, shp1)
ax = shp1.plot(cmap = 'jet', column = 'Layer', figsize=(10,10)) 
points_clip.plot(ax=ax,color='lime')
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pyproj/crs/crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# /tmp/ipykernel_2361/3141902393.py:6: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: +init=epsg:4326 +type=crs
# Right CRS: EPSG:4326
#
#   points_clip = gpd.clip(pgdf, shp1)
# <AxesSubplot:>

# %%
pgdf.to_file('output_data/park.shp')

# %% [markdown]
# ## Population

# %%
df  = shp1.merge(pop, on='Name', how='left')
df.plot("population", legend=True)
# Out:
# <AxesSubplot:>
