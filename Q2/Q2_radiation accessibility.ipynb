# %%
import requests
import json
import pandas as pd
import geopandas as gpd
from pandas.core.frame import DataFrame

# %%
farm=pd.read_csv('data/farm.csv')
shop=pd.read_csv('data/shop.csv')

# %%
def stod(slat,slng,dlat,dlng):#输入：起点纬度、起点经度、终点纬度、终点经度
    url ="http://api.map.baidu.com/direction/v2/transit?" #API地址
    ak = 'cGCdY6KHFma1t35LhDUZ13WI5qG1ni24' #秘钥
    tac_metro = r'&tactics_incity=5'
    real_url = url +"origin="+slat+","+slng+"&destination="+dlat+","+dlng+tac_metro+"&ak="+ak #完整的请求代码
    req = requests.get(real_url)
    t = req.text
    data = json.loads(t) #将数据保存在数组data中
    try:#防止某几条数据报错导致请求终止
        total_duration = data['result']["routes"][0]["duration"]/60
        stepstr = "Total time:"+str(total_duration) #获取该条数据总行程时间
        steps = data['result']["routes"][0]['steps'] #获取该条路径的所有步骤
        for step in steps:
            step_tructions = step[0]["instructions"]#每一步的介绍包括乘坐公交车或地铁线路名
            step_duration = step[0]["duration"]#每一步所花费的时间
            stepstr = stepstr+"/"+step_tructions+":"+str(step_duration/60)
    except:
        stepstr = None
    req.close()
    return stepstr #返回数据为总时长/第一步/第一步耗时/第二步/第二步耗时/...

# %%
def ave(lst):
    return sum(lst) / len(lst)

# %%
shop['name']
# Out:
# 0             华润万家(龙华店)
# 1             华润万家(益田店)
# 2             华润万家(沙井店)
# 3             华润万家(横岗店)
# 4             华润万家(宝安店)
#             ...
# 76           华润万家龙岗配送中心
# 77        华润万家便利超市(翠枫店)
# 78       华润万家便利超市(支六路店)
# 79            华润万家(麓园店)
# 80    华润万家便利超市(二十四区六巷店)
# Name: name, Length: 81, dtype: object

# %%
'''
for o in range (len(farm['lat'])):
    for d in range(len(shop['lat'])):
        print(stod(str(farm['lat'][o]),str(farm['lng'][o]),str(shop['lat'][d]),str(shop['lng'][d])))
        '''
# Out:
# Total time,176.93333333333334/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.55/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过7站到银湖汽车站②站,82.51666666666667/步行164米,2.2666666666666666/银湖站(D口)乘地铁9号线(前湾方向)经过2站到上梅林站,6.0/站内换乘 步行334米,4.633333333333334/上梅林站乘地铁4号线(牛湖方向)经过7站到龙华站(C口),19.0/步行427米,6.05
# Total time,150.61666666666667/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.55/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过4站到留医部②站,62.68333333333333/步行324米,4.583333333333333/翠竹站(C口)乘地铁3号线(福保方向)经过10站到石厦站(G口),22.0/步行524米,7.383333333333334
# Total time,220.66666666666666/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.55/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过7站到银湖汽车站②站,82.51666666666667/步行164米,2.2666666666666666/银湖站(D口)乘地铁9号线(前湾方向)经过8站到车公庙站,21.0/站内换乘 步行372米,5.15/车公庙站乘地铁11号线(碧头方向)经过13站到沙井站(C口),46.0/步行513米,7.266666666666667
# Total time,165.91666666666666/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.55/步行165米,2.35/大鹏中心①站乘818路(龙岗教苑总站方向)经过30站到双龙地铁站②站,81.7/步行250米,3.5/双龙站(D口)乘地铁3号线(福保方向)经过9站到塘坑站(A口),22.0/步行176米,2.4833333333333334
# Total time,209.68333333333334/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)经过12站到大鹏中心①站,20.55/同站换乘 步行135米,1.9166666666666667/大鹏中心①站乘E26路(福田交通枢纽公交场站方向)或高快巴士26号经过8站到黄贝岭地铁站①站,77.43333333333334/步行248米,3.433333333333333/黄贝岭站(A口)乘地铁5号线(赤湾方向)经过21站到灵芝站(A1口),53.0/步行1.4公里,20.016666666666666
# Total time,159.0/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.55/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过4站到留医部②站,62.68333333333333/步行324米,4.583333333333333/翠竹站(C口)乘地铁3号线(福保方向)经过8站到福田站,18.0/站内换乘 步行141米,1.95/福田站乘地铁2号线(赤湾方向)经过5站到侨香站(C口),10.0/步行378米,5.316666666666666
# Total time,137.13333333333333/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.55/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过2站到罗沙路莲塘②站,50.45/步行983米,13.966666666666667/仙湖路站(B2口)乘地铁2号线(赤湾方向)经过4站到湖贝站(A口),10.0/步行619米,8.75
# Total time,148.21666666666667/步行760米,10.85/榕树坑站乘M457路(葵涌总站方向)经过18站到大鹏中心①站,31.566666666666666/同站换乘 步行128米,1.8166666666666667/大鹏中心①站乘E26路(福田交通枢纽公交场站方向)经过5站到盐田区政府站,58.9/步行239米,3.3333333333333335/海山站(A2口)乘地铁2号线(赤湾方向)经过3站到莲塘站(D口),10.0/步行654米,9.25
# Total time,186.8/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.55/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过6站到体育馆②站,77.31666666666666/步行729米,10.3/黄木岗站(B口)乘地铁7号线(西丽湖方向)经过17站到珠光站(D口),39.0/步行439米,6.216666666666667
# Total time,90.56666666666666/步行1.4公里,20.3/大鹏所城站乘大鹏假日专线6号(盐田路地铁站方向)经过9站到盐田路地铁站,42.983333333333334/步行136米,1.8833333333333333/盐田路站(G口)乘地铁2号线(赤湾方向)经过3站到海山站(A1口),8.0/步行349米,4.9
# Total time,174.71666666666667/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)经过12站到大鹏中心①站,20.55/步行165米,2.35/大鹏中心①站乘M426路(坪山综合交通枢纽公交场站方向)经过14站到坪山火车站南广场站,60.28333333333333/同站换乘,0.0/坪山火车站南广场站乘M165路(华润城公交总站方向)经过4站到双龙地铁站③站,20.95/步行148米,2.05/双龙站(D口)乘地铁3号线(福保方向)经过3站到吉祥站(出口),6.0/步行1.3公里,19.2
# Total time,223.11666666666667/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.55/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过7站到银湖汽车站②站,82.51666666666667/步行165米,2.283333333333333/银湖站(D口)乘地铁6号线(松岗方向)经过21站到溪头站(D口),61.0/步行1.6公里,23.35
# Total time,157.88333333333333/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)经过12站到大鹏中心①站,20.55/同站换乘 步行135米,1.9166666666666667/大鹏中心①站乘E26路(福田交通枢纽公交场站方向)或高快巴士26号经过8站到黄贝岭地铁站①站,77.43333333333334/步行248米,3.433333333333333/黄贝岭站(A口)乘地铁5号线(赤湾方向)经过7站到下水径站(A口),16.0/步行369米,5.216666666666667
# Total time,176.95/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.55/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过4站到留医部②站,62.68333333333333/步行324米,4.583333333333333/翠竹站(C口)乘地铁3号线(双龙方向)经过4站到布吉站,11.0/站内换乘,0.5666666666666667/布吉站乘地铁5号线(赤湾方向)经过7站到民治站(A口),17.0/步行177米,2.45/民治地铁站乘M577路(民乐地铁站北公交场站方向)或M302路,333路,M152路,M193路经过3站到惠鑫公寓②站,8.0/步行295米,4.2
# Total time,168.91666666666666/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.55/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过4站到留医部②站,62.68333333333333/步行324米,4.583333333333333/翠竹站(C口)乘地铁3号线(福保方向)经过2站到老街站(B口),4.0/步行1.0公里,14.833333333333334/金威大厦站乘337路(海上田园方向)或73路,38路经过5站到福田村岗边坊站,9.866666666666667/步行629米,8.983333333333333
# Total time,174.1/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)经过12站到大鹏中心①站,20.55/同站换乘 步行135米,1.9166666666666667/大鹏中心①站乘E26路(福田交通枢纽公交场站方向)或高快巴士26号经过8站到黄贝岭地铁站①站,77.43333333333334/步行248米,3.433333333333333/黄贝岭站(A口)乘地铁5号线(赤湾方向)经过2站到太安站(B口),5.0/步行1.1公里,15.7/翠竹大厦站乘977路(田贝总站方向)经过3站到翠竹万家站,6.333333333333333/步行28米,0.4
# Total time,152.88333333333333/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.8/步行165米,2.35/大鹏中心①站乘M426路(坪山综合交通枢纽公交场站方向)经过11站到甲片村站,41.31666666666667/步行259米,3.7/坪山大道龙坪路口站乘M361路(华南城北公交总站方向)或M136路,深惠3A线经过12站到双龙地铁站②站,28.883333333333333/步行243米,3.4/双龙站(D口)乘地铁3号线(福保方向)经过2站到龙城广场站(D口),4.0/步行361米,5.1
# Total time,205.46666666666667/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.55/同站换乘 步行135米,1.9166666666666667/大鹏中心①站乘E26路(福田交通枢纽公交场站方向)或高快巴士26号经过12站到联合广场站,101.95/步行770米,10.866666666666667/岗厦站(E口)乘地铁1号线(机场东方向)经过12站到桃园站(B口),24.0/步行904米,12.85
# Total time,212.78333333333333/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)经过12站到大鹏中心①站,20.55/同站换乘 步行135米,1.9166666666666667/大鹏中心①站乘E26路(福田交通枢纽公交场站方向)或高快巴士26号经过8站到黄贝岭地铁站①站,77.43333333333334/步行248米,3.433333333333333/黄贝岭站(A口)乘地铁5号线(赤湾方向)经过23站到宝安中心站(F口),58.0/步行1.3公里,18.116666666666667
# Total time,171.18333333333334/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)经过12站到大鹏中心①站,20.55/同站换乘 步行135米,1.9166666666666667/大鹏中心①站乘E26路(福田交通枢纽公交场站方向)或高快巴士26号经过8站到黄贝岭地铁站①站,77.43333333333334/步行1.0公里,14.666666666666666/文锦站(C口)乘地铁9号线(前湾方向)经过9站到银湖站(D口),17.0/步行445米,6.283333333333333
# Total time,150.81666666666666/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)经过12站到大鹏中心①站,20.55/同站换乘 步行135米,1.9166666666666667/大鹏中心①站乘E26路(福田交通枢纽公交场站方向)或高快巴士26号经过8站到黄贝岭地铁站①站,77.43333333333334/步行248米,3.433333333333333/黄贝岭站(A口)乘地铁5号线(赤湾方向)经过4站到百鸽笼站(出口),10.0/步行295米,4.15
# Total time,162.71666666666667/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.55/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)或E26路,高快巴士26号经过3站到罗湖体育馆②站,54.36666666666667/步行584米,8.3/莲塘口岸站(C口)乘地铁2号线(赤湾方向)经过11站到景田站(D口),26.0/步行1.4公里,20.083333333333332
# Total time,188.1/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.55/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过4站到留医部②站,62.68333333333333/步行1.1公里,15.783333333333333/怡景站(D口)乘地铁5号线(赤湾方向)经过8站到杨美站(C口),19.0/步行466米,6.6/美家福百货站乘M584路(观景路公交首末站方向)或M572路经过7站到岗头发展大厦站,15.916666666666666/步行291米,4.15
# None
# Total time,156.18333333333334/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.55/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过7站到银湖汽车站②站,82.51666666666667/步行164米,2.2666666666666666/银湖站(D口)乘地铁9号线(前湾方向)经过4站到下梅林站(D口),11.0/步行455米,6.433333333333334
# Total time,147.81666666666666/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.55/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过7站到银湖汽车站②站,82.51666666666667/步行164米,2.2666666666666666/银湖站(D口)乘地铁9号线(文锦方向)经过3站到园岭站(B口),6.0/步行219米,3.066666666666667
# Total time,195.16666666666666/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.55/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过4站到留医部②站,62.68333333333333/步行1.1公里,15.783333333333333/怡景站(D口)乘地铁5号线(赤湾方向)经过21站到翻身站(A口),54.0/步行616米,8.733333333333333
# Total time,191.5/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.8/步行165米,2.35/大鹏中心①站乘M426路(坪山综合交通枢纽公交场站方向)经过13站到大东城站,44.81666666666667/步行485米,6.916666666666667/站前路东站乘M497路(龙岗长途客运站方向)经过9站到双龙地铁站②站,20.316666666666666/步行243米,3.4/双龙站(D口)乘地铁3号线(福保方向)经过3站到吉祥站(D口),6.0/步行895米,12.7/龙城中学站乘M386路(万凤路口方向)经过8站到龙岗天安数码城①站,17.066666666666666/步行267米,3.8
# Total time,199.78333333333333/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.55/步行165米,2.35/大鹏中心①站乘818路(龙岗教苑总站方向)经过30站到双龙地铁站②站,81.7/步行250米,3.5/双龙站(D口)乘地铁3号线(福保方向)经过11站到丹竹头站(A口),29.0/步行105米,1.45/丹竹头地铁站①站乘M233路(南湾沙塘布场站方向)经过5站到樟树布新村站,17.5/步行28米,0.4
# Total time,181.78333333333333/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.683333333333334/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过6站到体育馆②站,77.31666666666666/步行537米,7.6/体育中心站(B口)乘地铁6号线(松岗方向)经过5站到深圳北站,15.0/站内换乘,0.23333333333333334/深圳北站乘地铁4号线(牛湖方向)经过5站到清湖站(A1口),14.0/步行777米,11.033333333333333
# Total time,191.05/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.683333333333334/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过4站到留医部②站,62.68333333333333/步行324米,4.583333333333333/翠竹站(C口)乘地铁3号线(双龙方向)经过4站到布吉站,11.0/站内换乘,0.5666666666666667/布吉站乘地铁5号线(赤湾方向)经过7站到民治站(D口),17.0/步行1.1公里,15.1/铁路桥站乘M477路(观辅路公交首末站方向)或M202路,E37路,M354路经过3站到世纪春城站,5.9/步行534米,7.616666666666666
# Total time,198.06666666666666/步行760米,10.85/榕树坑站乘M457路(葵涌总站方向)经过18站到大鹏中心①站,31.616666666666667/步行158米,2.25/大鹏中心①站乘M426路(坪山综合交通枢纽公交场站方向)经过14站到坪山火车站南广场站,60.11666666666667/同站换乘,0.0/坪山火车站南广场站乘M165路(华润城公交总站方向)经过4站到双龙地铁站③站,20.816666666666666/步行148米,2.05/双龙站(D口)乘地铁3号线(福保方向)经过1站到南联站(C2口),2.0/步行376米,5.316666666666666/罗瑞合居民小组站乘M317路(龙岗信息学院总站方向)经过5站到回龙埔站,17.983333333333334/步行180米,2.566666666666667
# Total time,217.65/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,23.333333333333332/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过4站到留医部②站,124.31666666666666/步行324米,4.583333333333333/翠竹站(C口)乘地铁3号线(福保方向)经过8站到福田站,18.0/站内换乘 步行434米,6.016666666666667/福田站乘地铁11号线(碧头方向)经过1站到车公庙站(A口),3.0/步行179米,2.4833333333333334
# Total time,182.18333333333334/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.683333333333334/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过7站到银湖汽车站②站,82.51666666666667/步行164米,2.2666666666666666/银湖站(D口)乘地铁9号线(前湾方向)经过10站到深圳湾公园站(E口),27.0/步行1.1公里,16.3
# Total time,165.0/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)经过12站到大鹏中心①站,20.683333333333334/步行165米,2.35/大鹏中心①站乘M426路(坪山综合交通枢纽公交场站方向)经过14站到坪山火车站南广场站,60.28333333333333/步行484米,6.9/坪山综合交通枢纽公交场站乘M359路(观澜大水田总站方向)经过6站到双龙地铁站②站,21.0/步行250米,3.5/双龙站(D口)乘地铁3号线(福保方向)经过1站到南联站(B4口),2.0/步行355米,4.95
# Total time,205.6/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.683333333333334/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过6站到体育馆②站,77.31666666666666/步行537米,7.6/体育中心站(B口)乘地铁6号线(松岗方向)经过5站到深圳北站,15.0/站内换乘 步行84米,1.15/深圳北站乘地铁5号线(赤湾方向)经过10站到宝安中心站,27.0/站内换乘,0.1/宝安中心站乘地铁1号线(机场东方向)经过5站到后瑞站(B口),14.0/步行308米,4.333333333333333
# Total time,169.73333333333332/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)经过12站到大鹏中心①站,20.683333333333334/同站换乘 步行135米,1.9166666666666667/大鹏中心①站乘E26路(福田交通枢纽公交场站方向)或高快巴士26号经过8站到黄贝岭地铁站①站,77.43333333333334/步行248米,3.433333333333333/黄贝岭站(A口)乘地铁5号线(赤湾方向)经过11站到五和站(A口),25.0/步行560米,7.933333333333334
# Total time,205.68333333333334/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.683333333333334/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过4站到留医部②站,62.68333333333333/步行1.1公里,15.783333333333333/怡景站(D口)乘地铁5号线(赤湾方向)经过16站到西丽站(B口),42.0/步行458米,6.416666666666667/西丽法庭②站乘392路(世界之窗地铁公交接驳站方向)或325路经过3站到松坪山站,9.5/步行540米,7.7
# Total time,166.63333333333333/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.683333333333334/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过4站到留医部②站,62.68333333333333/步行324米,4.583333333333333/翠竹站(C口)乘地铁3号线(福保方向)经过7站到少年宫站(E口),16.0/步行682米,9.666666666666666/莲花山公园②站乘E18路(石龙公交场站方向)经过2站到景鹏大厦站,6.05/步行249米,3.55
# Total time,205.15/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,20.683333333333334/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过6站到体育馆②站,77.31666666666666/步行537米,7.6/体育中心站(B口)乘地铁6号线(科学馆方向)经过2站到科学馆站,4.0/站内换乘 步行277米,3.8333333333333335/科学馆站乘地铁1号线(机场东方向)经过13站到深大站(A3口),26.0/步行674米,9.5/深大北门①站乘324路(中山园场站方向)或M425路经过2站到中山公园东门站,7.3/步行210米,3.0
# Total time,276.35/步行759米,10.833333333333334/榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站,23.333333333333332/同站换乘,0.08333333333333333/大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过7站到银湖汽车站②站,144.11666666666667/步行164米,2.2666666666666666/银湖站(D口)乘地铁9号线(前湾方向)经过6站到景田站,15.0/站内换乘 步行121米,1.6666666666666667/景田站乘地铁2号线(赤湾方向)经过17站到蛇口港站(D1口),37.0/步行107米,1.4833333333333334/蛇口港地铁站乘M105路(秀峰工业区总站方向)或M400路,204路,M106路,331路,113路,M430路,226路,M409路经过1站到新时代广场站,2.4/步行222米,3.1666666666666665
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_62/3921799853.py in <module>
#       1 for o in range (len(farm['lat'])):
#       2     for d in range(len(shop['lat'])):
# ----> 3         print(stod(str(farm['lat'][o]),str(farm['lng'][o]),str(shop['lat'][d]),str(shop['lng'][d])))
#
# /tmp/ipykernel_62/1365222657.py in stod(slat, slng, dlat, dlng)
#       4     tac_metro = r'&tactics_incity=5'
#       5     real_url = url +"origin="+slat+","+slng+"&destination="+dlat+","+dlng+tac_metro+"&ak="+ak #完整的请求代码
# ----> 6     req = requests.get(real_url)
#       7     t = req.text
#       8     data = json.loads(t) #将数据保存在数组data中
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /opt/conda/envs/sds2021/lib/python3.9/http/client.py in getresponse(self)
#    1347         try:
#    1348             try:
# -> 1349                 response.begin()
#    1350             except ConnectionError:
#    1351                 self.close()
#
# /opt/conda/envs/sds2021/lib/python3.9/http/client.py in begin(self)
#     314         # read until we get a non-100 response
#     315         while True:
# --> 316             version, status, reason = self._read_status()
#     317             if status != CONTINUE:
#     318                 break
#
# /opt/conda/envs/sds2021/lib/python3.9/http/client.py in _read_status(self)
#     275
#     276     def _read_status(self):
# --> 277         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278         if len(line) > _MAXLINE:
#     279             raise LineTooLong("status line")
#
# /opt/conda/envs/sds2021/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
'''
for o in range (len(farm['lat'])):
    
    for d in range(len(shop['lat'])):
        s=str(stod(str(farm['lat'][o]),str(farm['lng'][o]),str(shop['lat'][d]),str(shop['lng'][d])))
        
        if s.find('乘地铁')==-1:
            if s.find('乘')!=-1:
                result='Only bus can arrive'
                table=1
                
            elif s.find('乘')==-1 and s.find('步行')!=-1:
                result='Within walking distance'
                table=2
                
            else:
                result='Wrong cause without walking data, bus data or metro data'
                table=3
        
        elif s.find('乘地铁')!=-1:
            result='Can be arrived by metro'
            first_split = s.split("/")
            dic= {'step':first_split}
            table = DataFrame(dic)
            table[['step','time']] = table['step'].str.split(':', expand=True)
    
        else:
            result='Wrong cause contradict result'
            table=404
        print(result)
        table
        '''
# Out:
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Wrong cause without walking data, bus data or metro data
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# Can be arrived by metro
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_62/3185725970.py in <module>
#       2
#       3     for d in range(len(shop['lat'])):
# ----> 4         s=str(stod(str(farm['lat'][o]),str(farm['lng'][o]),str(shop['lat'][d]),str(shop['lng'][d])))
#       5
#       6         if s.find('乘地铁')==-1:
#
# /tmp/ipykernel_62/3942548229.py in stod(slat, slng, dlat, dlng)
#       4     tac_metro = r'&tactics_incity=5'
#       5     real_url = url +"origin="+slat+","+slng+"&destination="+dlat+","+dlng+tac_metro+"&ak="+ak #完整的请求代码
# ----> 6     req = requests.get(real_url)
#       7     t = req.text
#       8     data = json.loads(t) #将数据保存在数组data中
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /opt/conda/envs/sds2021/lib/python3.9/http/client.py in getresponse(self)
#    1347         try:
#    1348             try:
# -> 1349                 response.begin()
#    1350             except ConnectionError:
#    1351                 self.close()
#
# /opt/conda/envs/sds2021/lib/python3.9/http/client.py in begin(self)
#     314         # read until we get a non-100 response
#     315         while True:
# --> 316             version, status, reason = self._read_status()
#     317             if status != CONTINUE:
#     318                 break
#
# /opt/conda/envs/sds2021/lib/python3.9/http/client.py in _read_status(self)
#     275
#     276     def _read_status(self):
# --> 277         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278         if len(line) > _MAXLINE:
#     279             raise LineTooLong("status line")
#
# /opt/conda/envs/sds2021/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
'''
for o in range (len(farm['lat'])):
    
    d_metro_time_total=[]
    d_walk_time_total=[]
    d_other_time_total=[]
    d_total_time=[]
    d_waiting_time=[]
    d_status=[]
    d_transfer=[]
    d_traffic_time=[]
    
    for d in range(len(shop['lat'])):
        s=stod(str(farm['lat'][o]),str(farm['lng'][o]),str(shop['lat'][d]),str(shop['lng'][d]))
        
        if s.find('乘地铁')==-1:
            if s.find('乘')!=-1:
                result='Only bus can arrive'
                i_walk_time_total=-10000
                i_other_time_total=10000
                
            elif s.find('乘')==-1 and s.find('步行')!=-1:
                result='Within walking distance'
                i_walk_time_total=10000
                i_other_time_total=-10000
                
            else:
                result='Wrong cause without walking data, bus data or metro data'
                i_walk_time_total=0
                i_other_time_total=0
            i_metro_time_total=0
            i_total_time=0
            i_waiting_time=0
            i_transfer=-10000
            i_traffic_time=0
        
        elif s.find('乘地铁')!=-1:
            result='Can be arrived by metro'
            i_transfer=s.count('站内换乘')
            first_split = s.split("/")
            dic= {'step':first_split}
            table = DataFrame(dic)
            table[['step','time']] = table['step'].str.split(',', expand=True)
            # table['time'] = table['time'].fillna(0)
    
            i_metro_time=[]
            i_walk_time=[]
            i_other_time=[]
            for i in range(len(table)):
                if table['step'][i].find('乘地铁')!=-1 or table['step'][i].find('换乘')!=-1:
                    i_metro_time.append(float(table['time'][i]))
                elif table['step'][i].find('乘地铁')==-1 and table['step'][i].find('步行')!=-1:
                    i_walk_time.append(float(table['time'][i]))
                elif table['step'][i].find('Total time')!=-1:
                    i_total_time=float(table['time'][i])
                else:
                    i_other_time.append(float(table['time'][i]))
    
            i_metro_time_total=sum(i_metro_time)
            i_walk_time_total=sum(i_walk_time)
            i_other_time_total=sum(i_other_time)
            i_traffic_time=i_metro_time_total+i_walk_time_total+i_other_time_total
            i_waiting_time=i_total_time-i_traffic_time
    
        else:
            result='Wrong cause contradict result'
            i_metro_time_total=404
            i_walk_time_total=404
            i_other_time_total=404
            i_total_time=404
            i_waiting_time=404
            i_transfer=404
            i_traffic_time=404
        
        d_metro_time_total.append(i_metro_time_total)
        d_walk_time_total.append(i_walk_time_total)
        d_other_time_total.append(i_other_time_total)
        d_total_time.append(i_total_time)
        d_waiting_time.append(i_waiting_time)
        d_status.append(result)
        d_transfer.append(i_transfer)
        d_traffic_time.append(i_traffic_time)
        
    d_dic={'Destination':shop['name'],
           'Status':d_status,
           'Metro_time':d_metro_time_total,
           'Walk_time':d_walk_time_total,
           'Other_time':d_other_time_total,
           'Traffic_time':d_traffic_time,
           'Waiting_time':d_waiting_time,
           'Total_time':d_total_time,
           'Transfer':d_transfer}
    d_final=DataFrame(d_dic)
        
    print(d_final)
        '''
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_62/2582291179.py in <module>
#      40             dic= {'step':first_split}
#      41             table = DataFrame(dic)
# ---> 42             table[['step','time']] = table['step'].str.split(',', expand=True)
#      43             # table['time'] = table['time'].fillna(0)
#      44
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3595             self._setitem_frame(key, value)
#    3596         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3597             self._setitem_array(key, value)
#    3598         elif isinstance(value, DataFrame):
#    3599             self._set_item_frame_value(key, value)
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    3632         else:
#    3633             if isinstance(value, DataFrame):
# -> 3634                 check_key_length(self.columns, key, value)
#    3635                 for k1, k2 in zip(key, value.columns):
#    3636                     self[k1] = value[k2]
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/indexers.py in check_key_length(columns, key, value)
#     426     if columns.is_unique:
#     427         if len(value.columns) != len(key):
# --> 428             raise ValueError("Columns must be same length as key")
#     429     else:
#     430         # Missing keys in columns are represented as -1
#
# ValueError: Columns must be same length as key

# %%
only_bus=[]
only_walk=[]
wrong_data=[]
metro=[]
walk=[]
other=[]
traffic=[]
waiting=[]
total=[]
transfer=[]

for o in range (len(farm['lat'])):
    
    d_metro_time_total=[]
    d_walk_time_total=[]
    d_other_time_total=[]
    d_total_time=[]
    d_waiting_time=[]
    d_status=[]
    d_transfer=[]
    d_traffic_time=[]
    
    for d in range(len(shop['lat'])):
        s=str(stod(str(farm['lat'][o]),str(farm['lng'][o]),str(shop['lat'][d]),str(shop['lng'][d])))
        
        if s.find('乘地铁')==-1:
            if s.find('乘')!=-1:
                result='Only bus can arrive'
                i_walk_time_total=-10000
                i_other_time_total=10000
                
            elif s.find('乘')==-1 and s.find('步行')!=-1:
                result='Within walking distance'
                i_walk_time_total=10000
                i_other_time_total=-10000
                
            else:
                result='Wrong cause without walking data, bus data or metro data'
                i_walk_time_total=0
                i_other_time_total=0
            i_metro_time_total=0
            i_total_time=0
            i_waiting_time=0
            i_transfer=-10000
            i_traffic_time=0
        
        elif s.find('乘地铁')!=-1:
            result='Can be arrived by metro'
            i_transfer=s.count('站内换乘')
            first_split = s.split("/")
            dic= {'step':first_split}
            table = DataFrame(dic)
            table[['step','time']] = table['step'].str.split(':', expand=True)
            # table['time'] = table['time'].fillna(0)
    
            i_metro_time=[]
            i_walk_time=[]
            i_other_time=[]
            for i in range(len(table)):
                if table['step'][i].find('乘地铁')!=-1 or table['step'][i].find('换乘')!=-1:
                    i_metro_time.append(float(table['time'][i]))
                elif table['step'][i].find('乘地铁')==-1 and table['step'][i].find('步行')!=-1:
                    i_walk_time.append(float(table['time'][i]))
                elif table['step'][i].find('Total time')!=-1:
                    i_total_time=float(table['time'][i])
                else:
                    i_other_time.append(float(table['time'][i]))
    
            i_metro_time_total=sum(i_metro_time)
            i_walk_time_total=sum(i_walk_time)
            i_other_time_total=sum(i_other_time)
            i_traffic_time=i_metro_time_total+i_walk_time_total+i_other_time_total
            i_waiting_time=i_total_time-i_traffic_time
    
        else:
            result='Wrong cause contradict result'
            i_metro_time_total=404
            i_walk_time_total=404
            i_other_time_total=404
            i_total_time=404
            i_waiting_time=404
            i_transfer=404
            i_traffic_time=404
        
        d_metro_time_total.append(i_metro_time_total)
        d_walk_time_total.append(i_walk_time_total)
        d_other_time_total.append(i_other_time_total)
        d_total_time.append(i_total_time)
        d_waiting_time.append(i_waiting_time)
        d_status.append(result)
        d_transfer.append(i_transfer)
        d_traffic_time.append(i_traffic_time)
        
    d_dic={'Destination':shop['name'],
           'Status':d_status,
           'Metro_time':d_metro_time_total,
           'Walk_time':d_walk_time_total,
           'Other_time':d_other_time_total,
           'Traffic_time':d_traffic_time,
           'Waiting_time':d_waiting_time,
           'Total_time':d_total_time,
           'Transfer':d_transfer}
    d_final=DataFrame(d_dic)
    
    f_only_bus=[]
    f_only_walk=[]
    f_wrong_data=[]
    f_metro=[]
    f_walk=[]
    f_other=[]
    f_traffic=[]
    f_waiting=[]
    f_total=[]
    f_transfer=[]
    for f in range (len(d_final['Destination'])):
        if d_final['Status'][f]=='Only bus can arrive':
            f_only_bus.append(d_final['Other_time'][f])
        elif d_final['Status'][f]=='Within walking distance':
            f_only_walk.append(d_final['Walk_time'][f])
        elif d_final['Status'][f]=='Can be arrived by metro':
            f_metro.append(d_final['Metro_time'][f])
            f_walk.append(d_final['Walk_time'][f])
            f_other.append(d_final['Other_time'][f])
            f_traffic.append(d_final['Traffic_time'][f])
            f_waiting.append(d_final['Waiting_time'][f])
            f_total.append(d_final['Total_time'][f])
            f_transfer.append(d_final['Transfer'][f])
        else:
            f_wrong_data.append(d_final['Transfer'][f])
    
    only_bus.append(len(f_only_bus))
    only_walk.append(len(f_only_walk))
    wrong_data.append(len(f_wrong_data))
    metro.append(ave(f_metro))
    walk.append(ave(f_walk))
    other.append(ave(f_other))
    traffic.append(ave(f_traffic))
    waiting.append(ave(f_waiting))
    total.append(ave(f_total))
    transfer.append(ave(f_transfer))

dic={'Origin':farm['name'],
     'Average_metro_time':metro,
     'Average_walk_time':walk,
     'Average_other_time':other,
     'Average_traffic_time':traffic,
     'Average_waiting_time':waiting,
     'Average_total_time':d_total_time,
     'Average_metro_line_transfer':total,
    'Count_of_only_bus_round':only_bus,
    'Count_of only_walk_round':only_walk,
    'Count_of_wrong_data':wrong_data}
#final=DataFrame(dic)
#final
dic
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# /opt/conda/envs/sds2021/lib/python3.9/http/client.py in getresponse(self)
#    1348             try:
# -> 1349                 response.begin()
#    1350             except ConnectionError:
#
# /opt/conda/envs/sds2021/lib/python3.9/http/client.py in begin(self)
#     315         while True:
# --> 316             version, status, reason = self._read_status()
#     317             if status != CONTINUE:
#
# /opt/conda/envs/sds2021/lib/python3.9/http/client.py in _read_status(self)
#     284             # sending a valid response.
# --> 285             raise RemoteDisconnected("Remote end closed connection without"
#     286                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     409             if read is False or not self._is_method_retryable(method):
# --> 410                 raise six.reraise(type(error), error, _stacktrace)
#     411             elif read is not None:
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# /opt/conda/envs/sds2021/lib/python3.9/http/client.py in getresponse(self)
#    1348             try:
# -> 1349                 response.begin()
#    1350             except ConnectionError:
#
# /opt/conda/envs/sds2021/lib/python3.9/http/client.py in begin(self)
#     315         while True:
# --> 316             version, status, reason = self._read_status()
#     317             if status != CONTINUE:
#
# /opt/conda/envs/sds2021/lib/python3.9/http/client.py in _read_status(self)
#     284             # sending a valid response.
# --> 285             raise RemoteDisconnected("Remote end closed connection without"
#     286                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /tmp/ipykernel_62/1776856907.py in <module>
#      22
#      23     for d in range(len(shop['lat'])):
# ---> 24         s=str(stod(str(farm['lat'][o]),str(farm['lng'][o]),str(shop['lat'][d]),str(shop['lng'][d])))
#      25
#      26         if s.find('乘地铁')==-1:
#
# /tmp/ipykernel_62/1911918443.py in stod(slat, slng, dlat, dlng)
#       4     tac_metro = r'&tactics_incity=5'
#       5     real_url = url +"origin="+slat+","+slng+"&destination="+dlat+","+dlng+tac_metro+"&ak="+ak #完整的请求代码
# ----> 6     req = requests.get(real_url)
#       7     t = req.text
#       8     data = json.loads(t) #将数据保存在数组data中
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %% [markdown]
# # __________________________________________ abandoned code________________________________________

# %%
s = '155.08333333333334/步行1.4公里,20.3/大鹏所城站乘大鹏假日专线6号(盐田路地铁站方向)经过9站到盐田路地铁站,42.13333333333333/步行136米,1.8833333333333333/盐田路站(G口)乘地铁2号线(赤湾方向)经过16站到市民中心站,43.0/站内换乘 步行196米,2.716666666666667/市民中心站乘地铁4号线(牛湖方向)经过10站到龙华站(C口),24.0/步行427米,6.05'
if s.find('乘地铁')==-1:
    if s.find('乘')!=-1:
        result='Only bus can arrive'
    elif s.find('乘')==-1 and s.find('步行')!=-1:
        result='Within walking distance'
    else:
        result='Wrong cause without walking data, bus data or metro data'
        
elif s.find('乘地铁')!=-1:
    result='Can be arrived by metro'
    transfer=s.count('换乘')
    first_split = s.split("/")
    dic= {'step':first_split}
    table = DataFrame(dic)
    table[['step','time']] = table['step'].str.split(',', expand=True)
    table['time'] = table['time'].fillna(0)
    
    i_metro_time=[]
    i_walk_time=[]
    i_other_time=[]
    for i in range(len(table)):
        if table['step'][i].find('乘地铁')!=-1 or table['step'][i].find('换乘')!=-1:
            i_metro_time.append(float(table['time'][i]))
        elif table['step'][i].find('乘地铁')==-1 and table['step'][i].find('步行')!=-1:
            i_walk_time.append(float(table['time'][i]))
        else:
            i_other_time.append(float(table['time'][i]))
    
    i_metro_time_total=sum(i_metro_time)
    i_walk_time_total=sum(i_walk_time)
    i_other_time_total=sum(i_other_time)
    total_time=i_metro_time_total+i_walk_time_total+i_other_time_total
    waiting_time=float(table['step'][0])-total_time
    
else:
    result='Wrong cause contradict result'

print(result)
print(total_time)
print(i_metro_time_total)
print(i_walk_time_total)
print(i_other_time_total)
print(waiting_time)
table
# Out:
# Can be arrived by metro
# 140.08333333333334
# 69.71666666666667
# 28.233333333333334
# 42.13333333333333
# 15.0
#                                   step                time
# 0                   155.08333333333334                   0
# 1                              步行1.4公里                20.3
# 2  大鹏所城站乘大鹏假日专线6号(盐田路地铁站方向)经过9站到盐田路地铁站   42.13333333333333
# 3                               步行136米  1.8833333333333333
# 4      盐田路站(G口)乘地铁2号线(赤湾方向)经过16站到市民中心站                43.0
# 5                          站内换乘 步行196米   2.716666666666667
# 6       市民中心站乘地铁4号线(牛湖方向)经过10站到龙华站(C口)                24.0
# 7                               步行427米                6.05

# %%
    o_only_bus_count=len(f_only_bus)
    o_only_walk_count=len(f_only_walk)
    o_wrong_data_count=len(f_wrong_data)
    o_ave_metro=ave(f_metro)
    o_ave_walk=ave(f_walk)
    o_ave_other=ave(f_other)
    o_ave_traffic=ave(f_traffic)
    o_ave_waiting=ave(f_waiting)
    o_ave_total=ave(f_total)
    o_ave_transfer=ave(f_transfer)
# Out:
#                                   step                time
# 0                   155.08333333333334                   0
# 1                              步行1.4公里                20.3
# 2  大鹏所城站乘大鹏假日专线6号(盐田路地铁站方向)经过9站到盐田路地铁站   42.13333333333333
# 3                               步行136米  1.8833333333333333
# 4      盐田路站(G口)乘地铁2号线(赤湾方向)经过16站到市民中心站                43.0
# 5                          站内换乘 步行196米   2.716666666666667
# 6       市民中心站乘地铁4号线(牛湖方向)经过10站到龙华站(C口)                24.0
# 7                               步行427米                6.05

# %%
table
# Out:
#                                       step                 time
# 0                        Total time,176.55                 None
# 1                                   步行759米   10.833333333333334
# 2     榕树坑站乘M471路(大鹏总站方向)或M457路经过12站到大鹏中心①站   20.566666666666666
# 3                                     同站换乘  0.08333333333333333
# 4  大鹏中心①站乘E11路(深圳北站交通枢纽公交场站方向)经过7站到银湖汽车站②站    82.11666666666666
# 5                                   步行164米   2.2666666666666666
# 6             银湖站(D口)乘地铁9号线(前湾方向)经过2站到上梅林站                  6.0
# 7                              站内换乘 步行334米    4.633333333333334
# 8             上梅林站乘地铁4号线(牛湖方向)经过7站到龙华站(C口)                 19.0
# 9                                   步行427米                 6.05

# %% [markdown]
# reference
#
# https://www.cnblogs.com/jqpy1994/p/10842795.html
#
# https://www.pythonf.cn/read/45820
